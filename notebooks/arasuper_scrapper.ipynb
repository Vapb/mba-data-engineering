# %%
import re
from requests import Session
from lxml.html import fromstring
from urllib.parse import urljoin

# %%
# Global vars
BASE_URL = 'https://www.arasuper.com.br/'
ALL_DEPS = '//ul[@class="menu-principal__items menu-principal__col menu-principal__col--1"]'
DEP_NAME = 'a/span/span'
DEP_URL = 'a/@href'
SUB_DEPS = 'div/div/ul/li' 

PRODUCT_NAME = 'div/div[3]/div/p[@class="item-produto__name"]'
PRODUCT_BRAND = 'div/div[3]/div/p[@class="item-produto__brand"]'
PRICE_ONE = 'div/div[3]/div/p[@class="item-produto__price just-one"]'
PRICE_TWO = 'div/div[3]/div/p[@class="item-produto__price"]'
PRICE_LEVE = 'div/div[3]/div/p[@class="item-produto__price price-leve"]'
PRICE_REGULAR = 'span[@class="item-produto__price-de"]'
PRICE = 'span[@class="item-produto__price-por"]'
PRODUCTS =  '//div[@class="products-list"]/a'

# %%
# Utils
def get_tree_from_url (session, url):
    response = session.get(url)
    return fromstring(response.text)

def extract_price(price):
    return int(re.sub(r"\s|R|\$|,", "", price)) / 100

def extract_url_code(url):
    code_match = re.search(r'/(\d+)/$', url)
    code = code_match.group(1)
    return code

def get_pages(url):
    i = 1
    while True:
        new_url = url + '?page=' + str(i)
        tree = get_tree_from_url(session, new_url)
        page_empty = tree.xpath('//div[@class="produto-lista empty-content"]')
        if page_empty != []:
            break
        else:
            yield tree
        i = i + 1

# %%
def get_departments(session):
    """
    Extract all departments from BASE_URL
    """
    departments = {}
    tree = get_tree_from_url(session, BASE_URL)
    for dep in tree.xpath(ALL_DEPS)[1]:
        depName = dep.xpath(DEP_NAME)[0].text_content()    
        subDeps = dep.xpath(SUB_DEPS)
        
        if subDeps != []: # Exists subDeps
            for sub in subDeps:
                subcontent = sub.text_content().split()
                if not(subcontent in [['Todos'],['Voltar']]):     # Erro Dept Todos e Voltar
                    subName = sub.xpath(DEP_NAME)[0].text_content()
                    url = BASE_URL + sub.xpath(DEP_URL)[0]
                    hierarchy = depName + ' > ' + subName
                    dep_id = f"COMP_{extract_url_code(url)}"
                    # INSERT ROW 
                    yield (url, hierarchy, dep_id)
        
        else: # Insert DEP
            url = BASE_URL + dep.xpath(DEP_URL)[0]
            dep_id = f"COMP_{extract_url_code(url)}"
            # INSERT ROW 
            yield (url, depName, dep_id)
    return departments

# %%
session = Session()

# %%
for x in get_departments(session):
    print(x)
# Out:
# ('https://www.arasuper.com.br/c/massas-resfriadas/580/', 'Alimentos > Massas Resfriadas', 'COMP_580')
# ('https://www.arasuper.com.br/c/torradas/562/', 'Alimentos > Torradas', 'COMP_562')
# ('https://www.arasuper.com.br/c/sal/546/', 'Alimentos > Sal', 'COMP_546')
# ('https://www.arasuper.com.br/c/queijo-ralado/530/', 'Alimentos > Queijo Ralado', 'COMP_530')
# ('https://www.arasuper.com.br/c/oleo/484/', 'Alimentos > Óleo', 'COMP_484')
# ('https://www.arasuper.com.br/c/mostarda/481/', 'Alimentos > Mostarda', 'COMP_481')
# ('https://www.arasuper.com.br/c/polpa-de-tomate/475/', 'Alimentos > Polpa de Tomate', 'COMP_475')
# ('https://www.arasuper.com.br/c/molho-tomate/474/', 'Alimentos > Molho Tomate', 'COMP_474')
# ('https://www.arasuper.com.br/c/manteigas/460/', 'Alimentos > Manteigas', 'COMP_460')
# ('https://www.arasuper.com.br/c/maionese/457/', 'Alimentos > Maionese', 'COMP_457')
# ('https://www.arasuper.com.br/c/frutas/453/', 'Alimentos > Frutas', 'COMP_453')
# ('https://www.arasuper.com.br/c/leite-de-coco/429/', 'Alimentos > Leite de Coco', 'COMP_429')
# ('https://www.arasuper.com.br/c/leite-condensado/425/', 'Alimentos > Leite Condensado', 'COMP_425')
# ('https://www.arasuper.com.br/c/massas/421/', 'Alimentos > Massas', 'COMP_421')
# ('https://www.arasuper.com.br/c/granola/398/', 'Alimentos > Granola', 'COMP_398')
# ('https://www.arasuper.com.br/c/geleias/391/', 'Alimentos > Geléias', 'COMP_391')
# ('https://www.arasuper.com.br/c/gelatinas/389/', 'Alimentos > Gelatinas', 'COMP_389')
# ('https://www.arasuper.com.br/c/feijao/362/', 'Alimentos > Feijão', 'COMP_362')
# ('https://www.arasuper.com.br/c/misturas-prontas/356/', 'Alimentos > Misturas Prontas', 'COMP_356')
# ('https://www.arasuper.com.br/c/extrato-de-tomate/353/', 'Alimentos > Extrato de Tomate', 'COMP_353')
# ('https://www.arasuper.com.br/c/leite-cremoso/312/', 'Alimentos > Leite Cremoso', 'COMP_312')
# ('https://www.arasuper.com.br/c/leites-e-compostos/295/', 'Alimentos > Leites e Compostos', 'COMP_295')
# ('https://www.arasuper.com.br/c/pascoa/291/', 'Alimentos > Pascoa', 'COMP_291')
# ('https://www.arasuper.com.br/c/natal/280/', 'Alimentos > Natal', 'COMP_280')
# ('https://www.arasuper.com.br/c/chas-e-ervas/261/', 'Alimentos > Chás e Ervas', 'COMP_261')
# ('https://www.arasuper.com.br/c/catchup/251/', 'Alimentos > Catchup', 'COMP_251')
# ('https://www.arasuper.com.br/c/sopas-e-cremes/244/', 'Alimentos > Sopas e Cremes', 'COMP_244')
# ('https://www.arasuper.com.br/c/caldos-e-temperos/238/', 'Alimentos > Caldos e Temperos', 'COMP_238')
# ('https://www.arasuper.com.br/c/cafe/229/', 'Alimentos > Café', 'COMP_229')
# ('https://www.arasuper.com.br/c/bolos-e-tortas/212/', 'Alimentos > Bolos e Tortas', 'COMP_212')
# ('https://www.arasuper.com.br/c/biscoitos/193/', 'Alimentos > Biscoitos', 'COMP_193')
# ('https://www.arasuper.com.br/c/chocolates/167/', 'Alimentos > Chocolates', 'COMP_167')
# ('https://www.arasuper.com.br/c/naturais/157/', 'Alimentos > Naturais', 'COMP_157')
# ('https://www.arasuper.com.br/c/azeite/143/', 'Alimentos > Azeite', 'COMP_143')
# ('https://www.arasuper.com.br/c/cereais-e-graos/141/', 'Alimentos > Cereais e Grãos', 'COMP_141')
# ('https://www.arasuper.com.br/c/arroz/126/', 'Alimentos > Arroz', 'COMP_126')
# ('https://www.arasuper.com.br/c/farinaceos/105/', 'Alimentos > Farináceos', 'COMP_105')
# ('https://www.arasuper.com.br/c/graos-empacotados/103/', 'Alimentos > Grãos Empacotados', 'COMP_103')
# ('https://www.arasuper.com.br/c/salgadinhos-e-snacks/101/', 'Alimentos > Salgadinhos e Snacks', 'COMP_101')
# ('https://www.arasuper.com.br/c/alimentacao-infantil/86/', 'Alimentos > Alimentação Infantil', 'COMP_86')
# ('https://www.arasuper.com.br/c/mel-e-melados/85/', 'Alimentos > Mel e Melados', 'COMP_85')
# ('https://www.arasuper.com.br/c/leite-po/79/', 'Alimentos > Leite Pó', 'COMP_79')
# ('https://www.arasuper.com.br/c/molhos/73/', 'Alimentos > Molhos', 'COMP_73')
# ('https://www.arasuper.com.br/c/balas-e-doces/72/', 'Alimentos > Balas e Doces', 'COMP_72')
# ('https://www.arasuper.com.br/c/produtos-etnicos/70/', 'Alimentos > Produtos Etnicos', 'COMP_70')
# ('https://www.arasuper.com.br/c/conservas-e-enlatados/61/', 'Alimentos > Conservas e Enlatados', 'COMP_61')
# ('https://www.arasuper.com.br/c/adocante/45/', 'Alimentos > Adocante', 'COMP_45')
# ('https://www.arasuper.com.br/c/acucar/35/', 'Alimentos > Açúcar', 'COMP_35')
# ('https://www.arasuper.com.br/c/confeitaria/33/', 'Alimentos > Confeitaria', 'COMP_33')
# ('https://www.arasuper.com.br/c/achocolatados/29/', 'Alimentos > Achocolatados', 'COMP_29')
# ('https://www.arasuper.com.br/c/temperos-e-especiarias/18/', 'Alimentos > Temperos e Especiarias', 'COMP_18')
# ('https://www.arasuper.com.br/c/doces/5/', 'Alimentos > Doces', 'COMP_5')
# ('https://www.arasuper.com.br/c/sandalias/553/', 'Bazar > Sandálias', 'COMP_553')
# ('https://www.arasuper.com.br/c/armarinho/491/', 'Bazar > Armarinho', 'COMP_491')
# ('https://www.arasuper.com.br/c/cama-mesa-e-banho/381/', 'Bazar > Cama Mesa e Banho', 'COMP_381')
# ('https://www.arasuper.com.br/c/camping-e-pesca/249/', 'Bazar > Camping e Pesca', 'COMP_249')
# ('https://www.arasuper.com.br/c/lampadas-pilhas-e-acendedores/176/', 'Bazar > Lampadas Pilhas e Acendedores', 'COMP_176')
# ('https://www.arasuper.com.br/c/eletro-portatil/174/', 'Bazar > Eletro Portátil', 'COMP_174')
# ('https://www.arasuper.com.br/c/brinquedos-infantis/163/', 'Bazar > Brinquedos Infantis', 'COMP_163')
# ('https://www.arasuper.com.br/c/limpeza-e-arrumacao/152/', 'Bazar > Limpeza e Arrumação', 'COMP_152')
# ('https://www.arasuper.com.br/c/festinha/150/', 'Bazar > Festinha', 'COMP_150')
# ('https://www.arasuper.com.br/c/utlidades-de-banheiro/136/', 'Bazar > Utlidades de Banheiro', 'COMP_136')
# ('https://www.arasuper.com.br/c/papelaria/120/', 'Bazar > Papelaria', 'COMP_120')
# ('https://www.arasuper.com.br/c/automotivo/109/', 'Bazar > Automotivo', 'COMP_109')
# ('https://www.arasuper.com.br/c/jardinagem/47/', 'Bazar > Jardinagem', 'COMP_47')
# ('https://www.arasuper.com.br/c/material-de-construcao/42/', 'Bazar > Material de Construção', 'COMP_42')
# ('https://www.arasuper.com.br/c/lazer-e-churrasco/24/', 'Bazar > Lazer e Churrasco', 'COMP_24')
# ('https://www.arasuper.com.br/c/utilidades-de-cozinha/11/', 'Bazar > Utilidades de Cozinha', 'COMP_11')
# ('https://www.arasuper.com.br/c/isotonico/414/', 'Bebidas > Isotônico', 'COMP_414')
# ('https://www.arasuper.com.br/c/vinhos/351/', 'Bebidas > Vinhos', 'COMP_351')
# ('https://www.arasuper.com.br/c/espumante/350/', 'Bebidas > Espumante', 'COMP_350')
# ('https://www.arasuper.com.br/c/energetico/339/', 'Bebidas > Energético', 'COMP_339')
# ('https://www.arasuper.com.br/c/cha/263/', 'Bebidas > Chá', 'COMP_263')
# ('https://www.arasuper.com.br/c/cerveja/257/', 'Bebidas > Cerveja', 'COMP_257')
# ('https://www.arasuper.com.br/c/mista/184/', 'Bebidas > Mista', 'COMP_184')
# ('https://www.arasuper.com.br/c/suco-e-nectar/182/', 'Bebidas > Suco e Nectar', 'COMP_182')
# ('https://www.arasuper.com.br/c/destilados/179/', 'Bebidas > Destilados', 'COMP_179')
# ('https://www.arasuper.com.br/c/bebida-de-soja/178/', 'Bebidas > Bebida de Soja', 'COMP_178')
# ('https://www.arasuper.com.br/c/vegetal/84/', 'Bebidas > Vegetal', 'COMP_84')
# ('https://www.arasuper.com.br/c/agua/49/', 'Bebidas > Água', 'COMP_49')
# ('https://www.arasuper.com.br/c/lactea/32/', 'Bebidas > Lactea', 'COMP_32')
# ('https://www.arasuper.com.br/c/linguicas-e-salsichas/445/', 'Açougue > Linguiças e Salsichas', 'COMP_445')
# ('https://www.arasuper.com.br/c/aves/134/', 'Açougue > Aves', 'COMP_134')
# ('https://www.arasuper.com.br/c/suinos/65/', 'Açougue > Suínos', 'COMP_65')
# ('https://www.arasuper.com.br/c/bovino/64/', 'Açougue > Bovino', 'COMP_64')
# ('https://www.arasuper.com.br/c/sabonetes/541/', 'Perfumaria > Sabonetes', 'COMP_541')
# ('https://www.arasuper.com.br/c/sabonete/540/', 'Perfumaria > Sabonete', 'COMP_540')
# ('https://www.arasuper.com.br/c/baby-care/282/', 'Perfumaria > Baby Care', 'COMP_282')
# ('https://www.arasuper.com.br/c/preservativo/209/', 'Perfumaria > Preservativo', 'COMP_209')
# ('https://www.arasuper.com.br/c/cabelo/138/', 'Perfumaria > Cabelo', 'COMP_138')
# ('https://www.arasuper.com.br/c/higiene-pessoal/116/', 'Perfumaria > Higiene Pessoal', 'COMP_116')
# ('https://www.arasuper.com.br/c/desodorantes/114/', 'Perfumaria > Desodorantes', 'COMP_114')
# ('https://www.arasuper.com.br/c/higiene-bucal/112/', 'Perfumaria > Higiene Bucal', 'COMP_112')
# ('https://www.arasuper.com.br/c/produtos-farmaceuticos/55/', 'Perfumaria > Produtos Farmacêuticos', 'COMP_55')
# ('https://www.arasuper.com.br/c/produtos-para-a-pele/51/', 'Perfumaria > Produtos Para a Pele', 'COMP_51')
# ('https://www.arasuper.com.br/c/toucador/27/', 'Perfumaria > Toucador', 'COMP_27')
# ('https://www.arasuper.com.br/c/esmaltes/26/', 'Perfumaria > Esmaltes', 'COMP_26')
# ('https://www.arasuper.com.br/c/absorventes/14/', 'Perfumaria > Absorventes', 'COMP_14')
# ('https://www.arasuper.com.br/c/inseticidas/409/', 'Limpeza > Inseticidas', 'COMP_409')
# ('https://www.arasuper.com.br/c/inseticida-e-raticida/407/', 'Limpeza > Inseticida e Raticida', 'COMP_407')
# ('https://www.arasuper.com.br/c/ceras/255/', 'Limpeza > Ceras', 'COMP_255')
# ('https://www.arasuper.com.br/c/limpeza-de-cozinha/218/', 'Limpeza > Limpeza de Cozinha', 'COMP_218')
# ('https://www.arasuper.com.br/c/desodorizador-de-ambiente/110/', 'Limpeza > Desodorizador de Ambiente', 'COMP_110')
# ('https://www.arasuper.com.br/c/limpeza-de-roupa/94/', 'Limpeza > Limpeza de Roupa', 'COMP_94')
# ('https://www.arasuper.com.br/c/limpeza-geral/66/', 'Limpeza > Limpeza Geral', 'COMP_66')
# ('https://www.arasuper.com.br/c/desinfetantes/58/', 'Limpeza > Desinfetantes', 'COMP_58')
# ('https://www.arasuper.com.br/c/tucupi/564/', 'Hortifruti > Tucupi', 'COMP_564')
# ('https://www.arasuper.com.br/c/ovos/492/', 'Hortifruti > Ovos', 'COMP_492')
# ('https://www.arasuper.com.br/c/alho/76/', 'Hortifruti > Alho', 'COMP_76')
# ('https://www.arasuper.com.br/c/folhagens/22/', 'Hortifruti > Folhagens', 'COMP_22')
# ('https://www.arasuper.com.br/c/legumes/8/', 'Hortifruti > Legumes', 'COMP_8')
# ('https://www.arasuper.com.br/c/frutas/2/', 'Hortifruti > Frutas', 'COMP_2')
# ('https://www.arasuper.com.br/c/pastas-e-pates/507/', 'Perecíveis > Pastas e Patês', 'COMP_507')
# ('https://www.arasuper.com.br/c/suinos/497/', 'Perecíveis > Suínos', 'COMP_497')
# ('https://www.arasuper.com.br/c/manteigas/461/', 'Perecíveis > Manteigas', 'COMP_461')
# ('https://www.arasuper.com.br/c/hamburguer/403/', 'Perecíveis > Hamburguer', 'COMP_403')
# ('https://www.arasuper.com.br/c/peixes/371/', 'Perecíveis > Peixes', 'COMP_371')
# ('https://www.arasuper.com.br/c/margarinas-e-creme-vegetal/320/', 'Perecíveis > Margarinas e Creme Vegetal', 'COMP_320')
# ('https://www.arasuper.com.br/c/queijos/309/', 'Perecíveis > Queijos', 'COMP_309')
# ('https://www.arasuper.com.br/c/requeijao-e-creme-de-ricota/308/', 'Perecíveis > Requeijão e Creme de Ricota', 'COMP_308')
# ('https://www.arasuper.com.br/c/aves-congeladas-e-resfriadas/307/', 'Perecíveis > Aves Congeladas e Resfriadas', 'COMP_307')
# ('https://www.arasuper.com.br/c/empanados/272/', 'Perecíveis > Empanados', 'COMP_272')
# ('https://www.arasuper.com.br/c/sobremesas/265/', 'Perecíveis > Sobremesas', 'COMP_265')
# ('https://www.arasuper.com.br/c/massas-resfriadas/246/', 'Perecíveis > Massas Resfriadas', 'COMP_246')
# ('https://www.arasuper.com.br/c/frutos-do-mar/239/', 'Perecíveis > Frutos do Mar', 'COMP_239')
# ('https://www.arasuper.com.br/c/legumes-congelados/221/', 'Perecíveis > Legumes Congelados', 'COMP_221')
# ('https://www.arasuper.com.br/c/pratos-prontos/211/', 'Perecíveis > Pratos Prontos', 'COMP_211')
# ('https://www.arasuper.com.br/c/frios-variados/208/', 'Perecíveis > Frios Variados', 'COMP_208')
# ('https://www.arasuper.com.br/c/leites-e-bebidas-lacteas/188/', 'Perecíveis > Leites e Bebidas Lactéas', 'COMP_188')
# ('https://www.arasuper.com.br/c/iogurtes/185/', 'Perecíveis > Iogurtes', 'COMP_185')
# ('https://www.arasuper.com.br/c/batata-pre-frita/170/', 'Perecíveis > Batata Pré Frita', 'COMP_170')
# ('https://www.arasuper.com.br/c/suinos-congelados/154/', 'Perecíveis > Suinos Congelados', 'COMP_154')
# ('https://www.arasuper.com.br/c/embutidos-salgados/122/', 'Perecíveis > Embutidos Salgados', 'COMP_122')
# ('https://www.arasuper.com.br/c/frutas-secas-e-castanhas/100/', 'Perecíveis > Frutas Secas e Castanhas', 'COMP_100')
# ('https://www.arasuper.com.br/c/sucos-e-polpas-de-frutas/20/', 'Perecíveis > Sucos e Polpas de Frutas', 'COMP_20')
# ('https://www.arasuper.com.br/c/gatos-e-seu-ambiente/90/', 'Pet Shop > Gatos e Seu Ambiente', 'COMP_90')
# ('https://www.arasuper.com.br/c/caes-e-seu-ambiente/88/', 'Pet Shop > Cães e Seu Ambiente', 'COMP_88')
# ('https://www.arasuper.com.br/c/aves-e-seu-ambiente/82/', 'Pet Shop > Aves e Seu Ambiente', 'COMP_82')
# ('https://www.arasuper.com.br/c/paes-producao-propria/499/', 'Padaria e Confeitaria > Pães Produção Própria', 'COMP_499')
# ('https://www.arasuper.com.br/c/paes/279/', 'Padaria e Confeitaria > Pães', 'COMP_279')
# ('https://www.arasuper.com.br/c/bolos/210/', 'Padaria e Confeitaria > Bolos', 'COMP_210')
# ('https://www.arasuper.com.br/c/paes-industrializados/207/', 'Padaria e Confeitaria > Pães Industrializados', 'COMP_207')
# ('https://www.arasuper.com.br/c/biscoitos-e-torradas/197/', 'Padaria e Confeitaria > Biscoitos e Torradas', 'COMP_197')

# %%
def get_pages(url):
    i = 1
    while True:
        new_url = url + '?page=' + str(i)
        print(new_url)
        tree = get_tree_from_url(session, new_url)
        page_empty = tree.xpath('//div[@class="produto-lista empty-content"]')
        if page_empty != []:
            break
        else:
            yield tree
        i = i + 1

# %%
TEST_URL = 'https://www.arasuper.com.br/c/vinhos/351/'

for i in get_pages(TEST_URL):
    print(i)
# Out:
# https://www.arasuper.com.br/c/vinhos/351/?page=1
# <Element html at 0x22388879ae0>
# https://www.arasuper.com.br/c/vinhos/351/?page=2
# <Element html at 0x22387874db0>
# https://www.arasuper.com.br/c/vinhos/351/?page=3
# <Element html at 0x22388879ae0>
# https://www.arasuper.com.br/c/vinhos/351/?page=4
# <Element html at 0x22388879bd0>
# https://www.arasuper.com.br/c/vinhos/351/?page=5
# <Element html at 0x2238787d950>
# https://www.arasuper.com.br/c/vinhos/351/?page=6
# <Element html at 0x22388879bd0>
# https://www.arasuper.com.br/c/vinhos/351/?page=7

# %%
# DONT NEED
def extract_products(page):
    products_info = []
    for product in page.xpath(PRODUCT_XPATH): 
        product_url = BASE_URL + product.xpath('@href')[0]
        product_name = product.xpath(NAME_XPATH)[0].text_content()
        product_brand = product.xpath(BRAND_XPATH)[0].text_content()
        
        if product.xpath(PRODUCT_ONE_XPATH): # One price
            regular_price = product.xpath(PRODUCT_ONE_XPATH)[0].text_content()
            regular_price = extract_price(regular_price)
            price = None
            exclusive_price = None
            
        elif product.xpath(PRODUCT_TWO_XPATH): # Regular Price and Price
            prices = product.xpath(PRODUCT_TWO_XPATH)[0]
            regular_price = prices.xpath(REGULAR_PRICE_XPATH)[0].text_content()
            regular_price = extract_price(regular_price)
            price = prices.xpath(PRICE_XPATH)[0].text_content()
            price = extract_price(price)
            exclusive_price = None
        
        else: # Only price LEVE
            prices = product.xpath(PRODUCT_LEVE_XPATH)[0]
            regular_price = prices.xpath(REGULAR_PRICE_XPATH)[0].text_content()
            regular_price = extract_price(regular_price)
            exclusive_price = prices.xpath(PRICE_XPATH)[0].text_content()
            exclusive_price = extract_price(exclusive_price)
            price = None
            print('LEVE', price, regular_price, exclusive_price)

        products_info.append(
            {
                'url': product_url,
                'name': product_name,
                'brand': product_brand,
                'price': price,
                'exclusive_price': exclusive_price,
                'regular_price': regular_price
            }
        )

    return products_info

# %%
for i in get_pages('https://www.arasuper.com.br/c/vinhos/351/'):
    print(i)
    for p in extract_products(i):
        print(p)
    print()
# Out:
# https://www.arasuper.com.br/c/vinhos/351/?page=1
# <Element html at 0x22388919e50>
# {'url': 'https://www.arasuper.com.br/p/vinho-nacional-galiotto-branco-seco-750ml/19485/', 'name': 'Vinho Nacional Galiotto Branco Seco 750ML  ', 'brand': 'GALIOTTO', 'price': None, 'exclusive_price': None, 'regular_price': 26.98}
# {'url': 'https://www.arasuper.com.br/p/vinho-nacional-galiotto-tinto-seco-750ml/19483/', 'name': 'Vinho Nacional Galiotto Tinto Seco 750ML ', 'brand': 'GALIOTTO', 'price': None, 'exclusive_price': None, 'regular_price': 26.98}
# {'url': 'https://www.arasuper.com.br/p/vinho-tinto-suave-nacional-galiotto-750ml/19482/', 'name': 'Vinho Tinto Suave Nacional Galiotto 750ML  ', 'brand': 'GALIOTTO', 'price': None, 'exclusive_price': None, 'regular_price': 26.98}
# {'url': 'https://www.arasuper.com.br/p/vinho-tinto-seco-nacional-collina-750ml/19462/', 'name': 'Vinho Tinto Seco Nacional Collina 750ML ', 'brand': 'COLLINA', 'price': None, 'exclusive_price': None, 'regular_price': 17.99}
# {'url': 'https://www.arasuper.com.br/p/vinho-chileno-casa-diablo-cabernet-sauvig-750ml/19259/', 'name': 'Vinho Chileno Casa Diablo Cabernet Sauvig  750ML', 'brand': 'DIABLO', 'price': None, 'exclusive_price': None, 'regular_price': 85.35}
# {'url': 'https://www.arasuper.com.br/p/vinho-nacional-aurora-colheira-tardia-tinto-500ml/18710/', 'name': 'Vinho Nacional Aurora Colheira Tardia Tinto 500ML', 'brand': 'AURORA', 'price': None, 'exclusive_price': None, 'regular_price': 29.98}
# {'url': 'https://www.arasuper.com.br/p/vinho-alemao-rheingau-eltviller-750ml/18524/', 'name': 'Vinho Alemao Rheingau Eltviller 750ML ', 'brand': 'RHEINGAU', 'price': None, 'exclusive_price': None, 'regular_price': 162.9}
# {'url': 'https://www.arasuper.com.br/p/vinho-italiano-lambrusco-anella-bianco-750ml/18526/', 'name': 'Vinho Italiano Lambrusco Anella Bianco 750ML ', 'brand': 'ANELLA ANDREANI', 'price': None, 'exclusive_price': None, 'regular_price': 53.49}
# {'url': 'https://www.arasuper.com.br/p/vinho-branco-alem-karl-resserve-lan-von-simmern-750ml/18519/', 'name': 'Vinho Branco Alem Karl Resserve Lan Von Simmern 750ML ', 'brand': 'KARL A RESS', 'price': None, 'exclusive_price': None, 'regular_price': 162.15}
# {'url': 'https://www.arasuper.com.br/p/vinho-argentino-gato-negro-malbec-750ml/18512/', 'name': 'Vinho Argentino Gato Negro Malbec 750ML ', 'brand': 'GATO NEGRO', 'price': None, 'exclusive_price': None, 'regular_price': 50.99}
# {'url': 'https://www.arasuper.com.br/p/vinho-chileno-reserva-moscato-750ml/18508/', 'name': 'Vinho Chileno Reserva Moscato 750ML ', 'brand': 'ALCA', 'price': None, 'exclusive_price': None, 'regular_price': 50.45}
# {'url': 'https://www.arasuper.com.br/p/vinho-chileno-cabernet-zaeli-suave-750ml/18507/', 'name': 'Vinho Chileno Cabernet Zaeli Suave 750ML', 'brand': 'ZAELI', 'price': None, 'exclusive_price': None, 'regular_price': 39.99}
# {'url': 'https://www.arasuper.com.br/p/vinho-chileno-gato-negro-carmenere-750ml/18509/', 'name': 'Vinho Chileno Gato Negro Carmenere  750ML ', 'brand': 'GATO NEGRO', 'price': None, 'exclusive_price': None, 'regular_price': 50.99}
# {'url': 'https://www.arasuper.com.br/p/vinho-nacional-aurora-pinto-bandeira-riesling-branco-750ml/18499/', 'name': 'Vinho Nacional Aurora Pinto Bandeira Riesling Branco 750ML ', 'brand': 'AURORA', 'price': None, 'exclusive_price': None, 'regular_price': 71.95}
# {'url': 'https://www.arasuper.com.br/p/vinho-chileno-tinto-reserva-8-rios-carmenere-750ml/18496/', 'name': 'Vinho Chileno Tinto Reserva 8 Rios Carmenere 750ML ', 'brand': '8 RIOS', 'price': None, 'exclusive_price': None, 'regular_price': 82.9}
# {'url': 'https://www.arasuper.com.br/p/vinho-chileno-meio-seco-diablo-red-750ml/18497/', 'name': 'Vinho Chileno Meio Seco Diablo Red 750ML', 'brand': 'DIABLO', 'price': None, 'exclusive_price': None, 'regular_price': 119.15}
# {'url': 'https://www.arasuper.com.br/p/vinho-tinto-portugues-antonio-saramago-750ml/18501/', 'name': 'Vinho Tinto Portugues Antonio Saramago 750ML', 'brand': 'ANTONIO SARAMAGO', 'price': None, 'exclusive_price': None, 'regular_price': 80.99}
# {'url': 'https://www.arasuper.com.br/p/vinho-chileno-reserva-merlot-750ml/18498/', 'name': 'Vinho Chileno Reserva Merlot 750ML ', 'brand': 'ALCA', 'price': None, 'exclusive_price': None, 'regular_price': 50.45}
# {'url': 'https://www.arasuper.com.br/p/vinho-argentino-tinto-mevi-cabernet-suavingnon-750ml/18492/', 'name': 'Vinho Argentino Tinto Mevi Cabernet Suavingnon 750ML ', 'brand': 'BODEGA MEVI', 'price': None, 'exclusive_price': None, 'regular_price': 56.9}
# {'url': 'https://www.arasuper.com.br/p/vinho-nacional-branco-valduga-arte-chardonnay-moscato-750ml/18493/', 'name': 'Vinho Nacional Branco Valduga Arte Chardonnay Moscato 750ML  ', 'brand': 'CASA VALDUGA', 'price': None, 'exclusive_price': None, 'regular_price': 60.55}
#
# https://www.arasuper.com.br/c/vinhos/351/?page=2
# <Element html at 0x223888a65e0>
# {'url': 'https://www.arasuper.com.br/p/vinho-nacional-branco-perini-arbo-moscato-750ml/18494/', 'name': 'Vinho Nacional Branco Perini Arbo Moscato 750ML ', 'brand': 'PERINI', 'price': None, 'exclusive_price': None, 'regular_price': 49.98}
# {'url': 'https://www.arasuper.com.br/p/vinho-nacional-aurora-reserva-tannat-750ml/18491/', 'name': 'Vinho Nacional Aurora Reserva Tannat  750ML ', 'brand': 'AURORA', 'price': None, 'exclusive_price': None, 'regular_price': 63.98}
# {'url': 'https://www.arasuper.com.br/p/vinho-nacional
98}
# {'url': 'https://www.arasuper.com.br/p/vinho-chalise-tinto-seco-750ml/2002/', 'name': 'Vinho Chalise Tinto Seco 750Ml', 'brand': 'CHALISE', 'price': None, 'exclusive_price': None, 'regular_price': 19.99}
# {'url': 'https://www.arasuper.com.br/p/vinho-tinto-quinta-do-morgado-cabernet-sauvignon-garrafa-750ml/1984/', 'name': 'Vinho Tinto Quinta Do Morgado Cabernet Sauvignon Garrafa 750Ml', 'brand': 'QUINTA DO MORGADO', 'price': None, 'exclusive_price': None, 'regular_price': 44.9}
# {'url': 'https://www.arasuper.com.br/p/vinho-country-wine-branco-suave-750ml/1707/', 'name': 'Vinho Country Wine Branco Suave 750Ml', 'brand': 'COUNTRY WINE', 'price': None, 'exclusive_price': None, 'regular_price': 22.98}
# {'url': 'https://www.arasuper.com.br/p/vinho-san-germain-tinto-suave-750ml/1680/', 'name': 'Vinho San Germain Tinto Suave 750Ml', 'brand': 'SAINT GERMAIN', 'price': None, 'exclusive_price': None, 'regular_price': 26.99}
# {'url': 'https://www.arasuper.com.br/p/vinho-branco-quinta-do-morgado-suave-garrafa-750ml/1683/', 'name': 'Vinho Branco Quinta Do Morgado Suave Garrafa 750Ml', 'brand': 'QUINTA DO MORGADO', 'price': None, 'exclusive_price': None, 'regular_price': 22.98}
# {'url': 'https://www.arasuper.com.br/p/vinho-marcus-james-cabernet-sauvignon-750ml/1685/', 'name': 'Vinho Marcus James Cabernet Sauvignon 750Ml', 'brand': 'MARCUS JAMES', 'price': None, 'exclusive_price': None, 'regular_price': 34.98}
# {'url': 'https://www.arasuper.com.br/p/vinho-branco-quinta-do-morgado-750ml/1684/', 'name': 'Vinho Branco Quinta Do Morgado 750Ml', 'brand': 'QUINTA DO MORGADO', 'price': None, 'exclusive_price': None, 'regular_price': 22.98}
# {'url': 'https://www.arasuper.com.br/p/vinho-san-germain-merlot-750ml/1679/', 'name': 'Vinho San Germain Merlot 750Ml', 'brand': 'SAINT GERMAIN', 'price': None, 'exclusive_price': None, 'regular_price': 26.98}
# {'url': 'https://www.arasuper.com.br/p/vinho-tinto-campo-largo-seco-garrafa-750ml/1555/', 'name': 'Vinho Tinto Campo Largo Seco Garrafa 750Ml', 'brand': 'CAMPO LARGO', 'price': None, 'exclusive_price': None, 'regular_price': 23.99}
#
# https://www.arasuper.com.br/c/vinhos/351/?page=6
# <Element html at 0x223888e7db0>
# LEVE None 17.98 15.99
# {'url': 'https://www.arasuper.com.br/p/vinho-campo-largo-tinto-suave-750ml/1554/', 'name': 'Vinho Campo Largo Tinto Suave 750Ml', 'brand': 'CAMPO LARGO', 'price': None, 'exclusive_price': None, 'regular_price': 23.99}
# {'url': 'https://www.arasuper.com.br/p/vinho-branco-campo-largo-suave-750ml/1553/', 'name': 'Vinho Branco Campo Largo Suave 750Ml', 'brand': 'CAMPO LARGO', 'price': None, 'exclusive_price': None, 'regular_price': 23.99}
# {'url': 'https://www.arasuper.com.br/p/vinho-tinto-brasileiro-dom-bosco-de-mesa-seco-garrafa-750ml/1546/', 'name': 'Vinho Tinto Brasileiro Dom Bosco De Mesa Seco Garrafa 750Ml', 'brand': 'DOM BOSCO', 'price': None, 'exclusive_price': 15.99, 'regular_price': 17.98}
# {'url': 'https://www.arasuper.com.br/p/vinho-country-wine-tinto-suave-750ml/557/', 'name': 'Vinho Country Wine Tinto Suave 750Ml', 'brand': 'COUNTRY WINE', 'price': None, 'exclusive_price': None, 'regular_price': 22.98}
#
# https://www.arasuper.com.br/c/vinhos/351/?page=7
