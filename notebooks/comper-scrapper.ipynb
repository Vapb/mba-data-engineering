# %%
import re
from requests import Session
from lxml.html import fromstring
from urllib.parse import urljoin
from unidecode import unidecode

# %%
BASE_URL = 'https://www.comper.com.br/'
JSON_DEPARTMENTS = 'https://www.comper.com.br/api/catalog_system/pub/category/tree/3/'

# %%
# INICIAR SESSION PARA TESTES
session = Session()

# %% [markdown]
# # Deparments

# %%
response = session.get(JSON_DEPARTMENTS).json()

# %%
def process_text(text):
    text = unidecode(text)
    text = text.replace(' ', '_').replace(',', '')
    text = text.lower()
    return text

# %%
def get_all_departments(json_response):
    all_departments = {}
    for department in json_response:
        department_name = department['name']
        if department['hasChildren']:
            for sub_department in department['children']:
                sub_department_name = sub_department['name']
                if sub_department['hasChildren']:
                    for sub_sub_department in sub_department['children']:
                        sub_sub_department_name = sub_sub_department['name']
                        category_name = process_text(f"{department_name}/{sub_department_name}/{sub_sub_department_name}")
                        all_departments[sub_sub_department['url']] = category_name     
                else:
                    category_name = process_text(f"{department_name}/{sub_department_name}")
                    all_departments[sub_department['url']] = category_name
        else:
            category_name = process_text(f"{department_name}")
            all_departments[sub_department['url']] = category_name
    
    return all_departments

# %%
# Get all deps inside store
get_all_departments(response)
# Out:
# {'https://www.comper.com.br/bebidas/aguas-chas-e-energeticos/agua': 'bebidas/aguas_chas_e_energeticos/agua',
#  'https://www.comper.com.br/bebidas/aguas-chas-e-energeticos/agua-de-coco': 'bebidas/aguas_chas_e_energeticos/agua_de_coco',
#  'https://www.comper.com.br/bebidas/aguas-chas-e-energeticos/chas': 'bebidas/aguas_chas_e_energeticos/chas',
#  'https://www.comper.com.br/bebidas/aguas-chas-e-energeticos/isotonicos-e-hidrotonicos': 'bebidas/aguas_chas_e_energeticos/isotonicos_e_hidrotonicos',
#  'https://www.comper.com.br/bebidas/aguas-chas-e-energeticos/energeticos': 'bebidas/aguas_chas_e_energeticos/energeticos',
#  'https://www.comper.com.br/bebidas/sucos-refrescos-e-refrig/bebidas-de-soja': 'bebidas/sucos_refrescos_e_refrig/bebidas_de_soja',
#  'https://www.comper.com.br/bebidas/sucos-refrescos-e-refrig/sucos-e-refrescos': 'bebidas/sucos_refrescos_e_refrig/sucos_e_refrescos',
# ...

# %% [markdown]
# # X

# %%
def set_token(session, sc):
    set_token_url = f"https://www.comper.com.br:443/Site/Track.aspx?sc={sc}"
    session.get(url=token_url)
    print('SGTS ',session.cookies['SGTS'])
    print('VTEXSC ',session.cookies['VTEXSC'])
    burp0_url = "https://www.comper.com.br:443/api/sessions/"
    burp0_json={"public":{}}
    session.post(burp0_url, cookies=session.cookies, json=burp0_json)

# %%
########## AJEITAR ESSA FUNÇÂO TOKEN
# Nao precisa fazer o fluxo perfeito só as funções

# %%
burp0_url = "https://www.comper.com.br:443/Site/Track.aspx?sc=1"
session.get(url=burp0_url)
session.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='ISSMB', value='ScreenMedia=0&UserAcceptMobile=False', port=None, port_specified=False, domain='.www.comper.com.br', domain_specified=True, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='SGTS', value='8BA93BB040C3D9E8B0D12BD62A3579EC', port=None, port_specified=False, domain='.www.comper.com.br', domain_specified=True, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=1698640963, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='VTEXSC', value='sc=1', port=None, port_specified=False, domain='.www.comper.com.br', domain_specified=True, domain_initial_dot=False, path='/', path_specified=True, secure=True, expires=1698706483, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='vtex_segment', value=
# ...

# %%
print('SGTS ',session.cookies['SGTS'])
print('VTEXSC ',session.cookies['VTEXSC'])
# Out:
# SGTS  8BA93BB040C3D9E8B0D12BD62A3579EC
# VTEXSC  sc=1

# %%
burp0_url = "https://www.comper.com.br:443/api/sessions/"
burp0_json={"public":{}}
session.post(burp0_url, cookies=session.cookies, json=burp0_json)
session.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='ISSMB', value='ScreenMedia=0&UserAcceptMobile=False', port=None, port_specified=False, domain='.www.comper.com.br', domain_specified=True, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='SGTS', value='8BA93BB040C3D9E8B0D12BD62A3579EC', port=None, port_specified=False, domain='.www.comper.com.br', domain_specified=True, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=1698640963, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='VTEXSC', value='sc=1', port=None, port_specified=False, domain='.www.comper.com.br', domain_specified=True, domain_initial_dot=False, path='/', path_specified=True, secure=True, expires=1698706483, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='vtex_segment', value=
# ...

# %%
burp0_url = "https://www.comper.com.br/mercearia/biscoitos-e-salgadinhos/salgadinho-e-snacks"
x = session.get(burp0_url, cookies=session.cookies)
session.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='ISSMB', value='ScreenMedia=0&UserAcceptMobile=False', port=None, port_specified=False, domain='.www.comper.com.br', domain_specified=True, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='SGTS', value='8BA93BB040C3D9E8B0D12BD62A3579EC', port=None, port_specified=False, domain='.www.comper.com.br', domain_specified=True, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=1698640963, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='VTEXSC', value='sc=1', port=None, port_specified=False, domain='.www.comper.com.br', domain_specified=True, domain_initial_dot=False, path='/', path_specified=True, secure=True, expires=1698706483, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='vtex_segment', value=
# ...

# %%
def get_pagination(tree):
    try:
        pager_element = tree.xpath('//div[@class="pager top"]')[0]
    except IndexError:
        return None, None
    pager_id = pager_element.attrib['id'].split('_')[1]
    pagination_script = tree.xpath('//script[contains(text(),'
                                   ' "window.location.hash '
                                   '= pageclickednumber")]')[0]
    script = pagination_script.text
    page_count = re.findall('pagecount_%s = (?P<a>\d+);' % pager_id, script)
    page_count = int(page_count[0])
    pagination_url = re.findall("\$\('\#ResultItems_%s'\).load\('"
                                "(?P<a>[^']+)'" % pager_id, script)[0]
    return page_count, pagination_url

# %%
get_pagination(fromstring(x.text))
# Out:
# (7,
#  '/buscapagina?fq=C%3a%2f1284%2f1343%2f1347%2f&PS=32&sl=8c91f63c-18aa-4c65-a2da-7ee53dbab287&cc=32&sm=0&PageNumber=')

# %%
test_url = BASE_URL + '/buscapagina?fq=C%3a%2f1284%2f1343%2f1347%2f&PS=32&sl=8c91f63c-18aa-4c65-a2da-7ee53dbab287&cc=32&sm=0&PageNumber=1'

# %%
test_url
# Out:
# 'https://www.comper.com.br//buscapagina?fq=C%3a%2f1284%2f1343%2f1347%2f&PS=32&sl=8c91f63c-18aa-4c65-a2da-7ee53dbab287&cc=32&sm=0&PageNumber=1'

# %%
y = session.get(test_url, cookies=session.cookies)

# %%
# Victor do futuro
# Validar com mais site (ver preço kg)
# Validar departmentos
# validar token
# Tabela deve ter Key para empresa e departamento e cep talvez

# %%
for item in fromstring(y.text).xpath('//div[@class="shelf-item"]'):
    row = {}
    row['sku'] = item.xpath('@data-product-id')[0]
    row['name'] = item.xpath('div/h3[@class="shelf-item__title"]/a')[0].text
    row['brand'] = item.xpath('div/div[@class="shelf-item__brand"]/a')[0].text
    row['url'] = item.xpath('div/h3/a/@href')[0]

    # If one of them is None copy other
    
    row['regular_price'] = item.xpath('div/div/div/span[@class="shelf-item__list-price"]')[0].text.strip()
    row['best_price'] = item.xpath('div/div/div/span/div/div/strong')[0].text
    print(row)
    print('-')
# Out:
# {'sku': '2845792', 'name': 'Batata Frita Pringles Original 104g', 'brand': 'Pringles', 'url': 'https://www.comper.com.br/batata-frita-pringles-original-104g/p', 'regular_price': 'R$ 14,99', 'best_price': 'R$ 10,90'}
# -
# {'sku': '2597799', 'name': 'Batata Palha Yoki Extra Fina 100g', 'brand': 'Yoki', 'url': 'https://www.comper.com.br/batata-palha-yoki-extra-fina-100g/p', 'regular_price': 'R$ 9,90', 'best_price': 'R$ 6,99'}
# -
# {'sku': '2798913', 'name': 'Salgadinho Torcida Sabor Queijo 38g', 'brand': 'Torcida', 'url': 'https://www.comper.com.br/salgadinho-torcida-sabor-queijo-38g/p', 'regular_price': 'R$ 1,99', 'best_price': 'R$ 1,59'}
# -
# {'sku': '2798859', 'name': 'Salgadinho Torcida Sabor Pimenta Mexicana 38g', 'brand': 'Torcida', 'url': 'https://www.comper.com.br/salgadinho-torcida-sabor-pimenta-mexicana-38g/p', 'regular_price': 'R$ 1,99', 'best_price': 'R$ 1,59'}
# -
# ...

# %%
INSERT INTO supermercado (nome, franquia, endereco, estado, cidade, url, cep)
VALUES
  ('comper - jardim italia', 'comper', 'Av. Gov. Dante Martins de Oliveira, 1093', 'Mato Grosso', 'Cuiaba',  'https://www.comper.com.br/?sc=1', '78050170'),
  ('BMW', 'M1', 1978),
  ('Toyota', 'Celica', 1975);

# %%
  const zipCodeStore = [  
    {
        "name": "MT", # Cuiabá - Jardim Itália
        'Av. Gov. Dante Martins de Oliveira, 1093' - Jardim Itália, Cuiabá - MT, 78050-170
        "sellerChannel": 1,
    {
        "name": "MS", # Campo Grande - Itanhangá Park
        R. Joaquim Murtinho, 1679 - Itanhangá Park, Campo Grande - MS, 79003-027
        "sellerChannel": 2,        
    },
    {
        "name": "DF", # Brasília - Norte (Águas Claras)
        R. 36 Norte, S/N - Lt. 05 - Águas Claras, Brasília - DF, 71919-180
        "sellerChannel": 3,
 {
        "name": "MS2", # Dourados - Vila Alba
     Av. Marcelino Pires, 3855 - Centro, Dourados - MS, 79801-002
        "sellerChannel": 5,
       
    },
    {
        "name": "MT2", # Rondonopolis - Centro
        Av. Rui Barbosa, 1859 - Centro, Rondonópolis - MT, 78700-130
        "sellerChannel": 6,       
    },
       {
        "name": "DF2", # Brasília - Sobradinho
        Lote 12/16 - Comper Center Sobradinho, Q 14 - Sobradinho, Brasília - DF, 73050-140
        "sellerChannel": 4,

# %%
INSERT INTO supermercado (nome, franquia, endereco, estado, cidade, bairro, url, cep)
VALUES
  ('comper - cuiaba - jardim italia',          'comper',  'av. gov. dante martins de oliveira, 1093', 'mato grosso',        'cuiaba',       'jardim italia',   'https://www.comper.com.br/?sc=1', '78050170'),
  ('comper - campo grande - itanhanga park',   'comper',  'r. joaquim murtinho, 1679',                'mato grosso do sul', 'campo grande', 'itanhanga park',  'https://www.comper.com.br/?sc=2', '79003027'),
  ('comper - brasilia - aguas claras',         'comper',  'r. 36 norte, s/n - lt. 05',                'distrito federal',   'brasilia',     'aguas claras',    'https://www.comper.com.br/?sc=3', '71919180'),
  ('comper - brasilia - sobradinho',           'comper',  'lote 12/16, q 14',                         'distrito federal',   'brasilia',     'sobradinho',      'https://www.comper.com.br/?sc=4', '73050140'),
  ('comper - dourados - vila alba',            'comper',  'av. marcelino pires, 3855',                'mato grosso do sul', 'dourados',     'vila alba',       'https://www.comper.com.br/?sc=5', '79801002'),
  ('comper - rondonopolis - centro',           'comper',  'av. rui barbosa, 1859',                    'mato grosso',        'rondonopolis', 'centro',          'https://www.comper.com.br/?sc=6', '78700130'),
  ('arasuper - rio branco - aviario',          'arasuper','av. gov. dante martins de oliveira, 1093', 'acre',               'rio branco',   'aviario',         'https://www.arasuper.com.br/',    '69900854'),
;
